# %%
import pandas as pd

# %%
ruta= "C:\\Users\\Francisco\\Downloads\\capsulas.xlsx"
pruebas= pd.read_excel(ruta)

# %%
pruebas
# Out:
#    corrida_id                  inicio                      Fin      condicion  \
# 0           1     2025-12-12 11:55:00      2025-12-12 00:25:00  Sin condicion
# 1           1     2025-12-12 11:55:00      2025-12-12 00:25:00  Sin condicion
# 2           2     2025-12-12 12:35:00  12/12/2025  13:01:00 PM  Con condicion
# 3           2     2025-12-13 12:35:00  12/12/2025  13:01:00 PM  Con condicion
# 4           3     2025-12-12 13:02:00      2025-12-12 13:40:00  Sin condicion
# 5           3     2025-12-12 13:02:00      2025-12-12 13:40:00  Sin condicion
# 6           4     2025-12-12 13:45:00      2025-12-12 14:08:00  Con condicion
# 7           4     2025-12-12 13:45:00      2025-12-12 14:08:00  Con condicion
# 8           5  15/12/2025  3:45:00 PM   15/12/2025  4:15:00 PM  Con condicion
# 9           5  15/12/2025  3:45:00 PM   15/12/2025  4:15:00 PM  Con condicion
#
#          Sublote Cod_filtro  ID_cap  frr_faltante  frr_insuficiente  \
# ...
